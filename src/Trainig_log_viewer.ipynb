# %% [markdown]
# # Loading Trained Model

# %%
import torch
import matplotlib.pyplot as plt

from LogViewer import LogViewer

# %%
"""Dataset selection"""
# DATASET = "CIFAR10"
# DATASET = "CIFAR100"
DATASET = "ImageNet2012"

"""Model selection for CIFAR"""
NUM_LAYERS_LEVEL = 5

"""Dataset parameters"""
BATCH = 256
SHUFFLE = True
NUMOFWORKERS = 8
PIN_MEMORY = True
SPLIT_RATIO = 0

"""optimizer parameters"""
OPTIMIZER = "SGD"
# OPTIMIZER = "Adam"
# OPTIMIZER = "Adam_decay"

"""Learning rate scheduler parameters"""
# LOAD_BEFORE_TRAINING = False
LOAD_BEFORE_TRAINING = True
NUM_EPOCHS = 500
# scheduler_patience_mapping = {"CIFAR10": 200, "CIFAR100": 200, "ImageNet2012": 30}

"""Early stopping parameters"""
EARLYSTOPPINGPATIENCE = 90
file_path = ""
if DATASET == "ImageNet2012":
    file_path = f"{DATASET}/MyResNet34_{BATCH}_{OPTIMIZER}"
else:
    file_path = f"{DATASET}/MyResNet{NUM_LAYERS_LEVEL*6+2}_{BATCH}_{OPTIMIZER}"

if SPLIT_RATIO != 0:
    file_path += f"_{int(SPLIT_RATIO*100)}"

# %%
checkpoint = torch.load(
    "../logs/" + file_path + ".pth.tar",
    map_location=lambda storage, loc: storage.cuda("cuda"),
)

logs = checkpoint["logs"]

print("Suceessfully loaded the All setting and Log file.")
# Out:
# Suceessfully loaded the All setting and Log file.

# %%
viewer = LogViewer(logs)
# viewer.draw(start=4980, range=200)
viewer.draw()

# %%
viewer.print_len()
# Out:
# Num of train logs :  53
# Num of train logs :  53
# Num of valid logs :  53
# Num of valid logs :  53
# Num of test  logs :  0
# Num of test  logs :  0
# Num of lr    logs :  53

# %%
viewer.print_all()
# Out:
# 1 epoch: train_loss=0.0010, train_acc=0.1049, valid_loss=4.6578, valid_acc=0.1364, lr=0.1000
# 2 epoch: train_loss=0.0008, train_acc=0.2028, valid_loss=3.7564, valid_acc=0.2626, lr=0.1000
# 3 epoch: train_loss=0.0007, train_acc=0.2797, valid_loss=3.2797, valid_acc=0.3386, lr=0.1000
# 4 epoch: train_loss=0.0007, train_acc=0.3217, valid_loss=3.0190, valid_acc=0.3892, lr=0.1000
# 5 epoch: train_loss=0.0006, train_acc=0.4266, valid_loss=2.8776, valid_acc=0.4072, lr=0.1000
# 6 epoch: train_loss=0.0006, train_acc=0.3706, valid_loss=2.9666, valid_acc=0.3939, lr=0.1000
# 7 epoch: train_loss=0.0006, train_acc=0.3706, valid_loss=2.7707, valid_acc=0.4311, lr=0.1000
# 8 epoch: train_loss=0.0006, train_acc=0.3497, valid_loss=2.5864, valid_acc=0.4579, lr=0.1000
# 9 epoch: train_loss=0.0006, train_acc=0.3497, valid_loss=2.5969, valid_acc=0.4538, lr=0.1000
# 10 epoch: train_loss=0.0006, train_acc=0.4126, valid_loss=2.6141, valid_acc=0.4665, lr=0.1000
# 11 epoch: train_loss=0.0006, train_acc=0.3636, valid_loss=2.6270, valid_acc=0.4707, lr=0.1000
# 12 epoch: train_loss=0.0006, train_acc=0.4476, valid_loss=2.5680, valid_acc=0.4700, lr=0.1000
# 13 epoch: train_loss=0.0006, train_acc=0.3497, valid_loss=2.6717, valid_acc=0.4589, lr=0.1000
# 14 epoch: train_loss=0.0006, train_acc=0.4126, valid_loss=2.5719, valid_acc=0.4810, lr=0.1000
# 15 epoch: train_loss=0.0006, train_acc=0.3776, valid_loss=2.6567, valid_acc=0.4662, lr=0.1000
# 16 epoch: train_loss=0.0005, train_acc=0.4336, valid_loss=2.5368, valid_acc=0.4839, lr=0.1000
# 17 epoch: train_loss=0.0006, train_acc=0.3776, valid_loss=2.6874, valid_acc=0.4474, lr=0.1000
# 18 epoch: train_loss=0.0005, train_acc=0.4196, valid_loss=2.5391, valid_acc=0.4804, lr=0.1000
# 19 epoch: train_loss=0.0006, train_acc=0.4476, valid_loss=2.5098, valid_acc=0.4818, lr=0.1000
# 20 epoch: train_loss=0.0006, train_acc=0.4196, valid_loss=2.5353, valid_acc=0.4871, lr=0.1000
# 21 epoch: train_loss=0.0006, train_acc=0.3916, valid_loss=2.5295, valid_acc=0.4919, lr=0.1000
# 22 epoch: train_loss=0.0005, train_acc=0.4196, valid_loss=2.4779, valid_acc=0.4868, lr=0.1000
# 23 epoch: train_loss=0.0005, train_acc=0.4406, valid_loss=2.4096, valid_acc=0.5076, lr=0.1000
# 24 epoch: train_loss=0.0006, train_acc=0.3427, valid_loss=2.4243, valid_acc=0.4919, lr=0.1000
# 25 epoch: train_loss=0.0006, train_acc=0.3776, valid_loss=2.5221, valid_acc=0.4846, lr=0.1000
# 26 epoch: train_loss=0.0006, train_acc=0.4126, valid_loss=2.5393, valid_acc=0.4780, lr=0.1000
# 27 epoch: train_loss=0.0005, train_acc=0.4755, valid_loss=2.4781, valid_acc=0.4914, lr=0.1000
# 28 epoch: train_loss=0.0005, train_acc=0.4266, valid_loss=2.5318, valid_acc=0.4870, lr=0.1000
# 29 epoch: train_loss=0.0006, train_acc=0.3916, valid_loss=2.4461, valid_acc=0.5066, lr=0.1000
# 30 epoch: train_loss=0.0003, train_acc=0.6084, valid_loss=1.7187, valid_acc=0.6437, lr=0.0100
# 31 epoch: train_loss=0.0004, train_acc=0.5455, valid_loss=1.6553, valid_acc=0.6564, lr=0.0100
# 32 epoch: train_loss=0.0004, train_acc=0.5594, valid_loss=1.6095, valid_acc=0.6637, lr=0.0100
# 33 epoch: train_loss=0.0004, train_acc=0.4965, valid_loss=1.5819, valid_acc=0.6673, lr=0.0100
# 34 epoch: train_loss=0.0004, train_acc=0.5385, valid_loss=1.5847, valid_acc=0.6713, lr=0.0100
# 35 epoch: train_loss=0.0004, train_acc=0.5594, valid_loss=1.5764, valid_acc=0.6711, lr=0.0100
# 36 epoch: train_loss=0.0004, train_acc=0.5734, valid_loss=1.5599, valid_acc=0.6696, lr=0.0100
# 37 epoch: train_loss=0.0003, train_acc=0.5944, valid_loss=1.5576, valid_acc=0.6739, lr=0.0100
# 38 epoch: train_loss=0.0004, train_acc=0.5664, valid_loss=1.5764, valid_acc=0.6682, lr=0.0100
# 39 epoch: train_loss=0.0004, train_acc=0.5524, valid_loss=1.5703, valid_acc=0.6697, lr=0.0100
# 40 epoch: train_loss=0.0004, train_acc=0.5944, valid_loss=1.5815, valid_acc=0.6735, lr=0.0100
# 41 epoch: train_loss=0.0004, train_acc=0.5664, valid_loss=1.5583, valid_acc=0.6705, lr=0.0100
# 42 epoch: train_loss=0.0004, train_acc=0.5175, valid_loss=1.5631, valid_acc=0.6698, lr=0.0100
# 43 epoch: train_loss=0.0004, train_acc=0.5385, valid_loss=1.5977, valid_acc=0.6647, lr=0.0100
# 44 epoch: train_loss=0.0003, train_acc=0.6643, valid_loss=1.3860, valid_acc=0.7086, lr=0.0010
# 45 epoch: train_loss=0.0003, train_acc=0.6294, valid_loss=1.3704, valid_acc=0.7113, lr=0.0010
# 46 epoch: train_loss=0.0003, train_acc=0.5594, valid_loss=1.3558, valid_acc=0.7124, lr=0.0010
# 47 epoch: train_loss=0.0003, train_acc=0.6923, valid_loss=1.3576, valid_acc=0.7113, lr=0.0010
# 48 epoch: train_loss=0.0003, train_acc=0.6434, valid_loss=1.3389, valid_acc=0.7159, lr=0.0010
# 49 epoch: train_loss=0.0003, train_acc=0.5664, valid_loss=1.3377, valid_acc=0.7155, lr=0.0010
# 50 epoch: train_loss=0.0003, train_acc=0.6434, valid_loss=1.3300, valid_acc=0.7170, lr=0.0010
# 51 epoch: train_loss=0.0004, train_acc=0.5874, valid_loss=1.3224, valid_acc=0.7198, lr=0.0010
# 52 epoch: train_loss=0.0003, train_acc=0.6783, valid_loss=1.3326, valid_acc=0.7174, lr=0.0010
# 53 epoch: train_loss=0.0003, train_acc=0.6364, valid_loss=1.3244, valid_acc=0.7183, lr=0.0010

# %% [markdown]
# - 주피터노트북 output set
# - @tag:notebookOutputLayout
